# %% [markdown]
# **PANDAS**

# %% [markdown]
# **Pandas** stands for python data analysis
#
# It stands for open source software library  designed for data manipulation and analysis.
#
# built top of NumPy , efficiently manages large datasets, offering tools for data cleaning , transformation and analysis.
#
# Revolves around two primary data structure : **Series (1D)** and **DataFrame(2D)**

# %% [markdown]
# **What is Pandas used for ?**
#
#
# Reading and writing data from various file formats like CSV, Excel and SQL databases.
#
#
# Cleaning and preparing data (handling missing values, filtering, removing duplicates).
#
#
# Merging, joining, and reshaping datasets.
#
#
# Performing statistical analysis and descriptive statistics.
#
#
# Visualizing data quickly.

# %% [markdown]
# Pandas **Series** is a one-dimensional labeled array that can hold data of any type (integer, float, string, Python objects, etc.). It is similar to a column in an Excel spreadsheet or a database table.
#
# **Key Features of Pandas Series**
#
# Supports integer-based and label based indexing.
#
#
# Stores heterogeneous data types.
#
# Offers a variety of built in methods for data manipulation and analysis.

# %% [markdown]
# **Creating Pandas Series**

# %%
import pandas as pd 
import numpy as np

# %%
data=[1,2,3,4,5]
pd.Series(data)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# **Position- based Indexing**

# %%
data =np.array(['p','a','l','a','k'])
ser = pd.Series(data)

print(ser[:5])

print(ser[:4])
# Out:
# 0    p
# 1    a
# 2    l
# 3    a
# 4    k
# dtype: str
# 0    p
# 1    a
# 2    l
# 3    a
# dtype: str

# %% [markdown]
# **Label -Based Indexing**

# %%
data = np.array(['p','a','l','a','k'])
ser= pd.Series(data,index=[10,11,12,13,14])

print(ser)

print(ser[14])

ser[13]
# Out:
# 10    p
# 11    a
# 12    l
# 13    a
# 14    k
# dtype: str
# k
# 'a'

# %% [markdown]
# **Indexing Using .loc[]**

# %%
df= pd.read_csv(r"C:\Users\dpand\OneDrive\Desktop\AI engineer learning - goal 2027\Machine Learning.py\Libraries\nba.csv")
ser = pd.Series(df['Name'])
data = ser.head(10)
data

data.loc[3:6]
# Out:
# 3      R.J. Hunter
# 4    Jonas Jerebko
# 5     Amir Johnson
# 6    Jordan Mickey
# Name: Name, dtype: str

# %%
  
df = pd.read_csv(r"C:\Users\dpand\OneDrive\Desktop\AI engineer learning - goal 2027\Machine Learning.py\Libraries\nba.csv")  
   
ser = pd.Series(df['Name']) 
data = ser.head(10)
data
# Out:
# 0    Avery Bradley
# 1      Jae Crowder
# 2     John Holland
# 3      R.J. Hunter
# 4    Jonas Jerebko
# 5     Amir Johnson
# 6    Jordan Mickey
# 7     Kelly Olynyk
# 8     Terry Rozier
# 9     Marcus Smart
# Name: Name, dtype: str

# %%
data.iloc[3:6]
# Out:
# 3      R.J. Hunter
# 4    Jonas Jerebko
# 5     Amir Johnson
# Name: Name, dtype: str

# %% [markdown]
# **Binary operation on Pandas Series**

# %%
ser1 = pd.Series([1, 2, 3], index=['A', 'B', 'C'])
ser2 = pd.Series([4, 5, 6], index=['A', 'B', 'C'])

df_sum = ser1.add(ser2)
print(df_sum)

df_sub = ser1.sub(ser2)
print(df_sum)

df_mul = ser1.mul(ser2)
print(df_mul)

df_div = ser1.div(ser2)
print(df_div)


df_pow = ser1.pow(ser2)
print(df_pow)
# Out:
# A    5
# B    7
# C    9
# dtype: int64
# A    5
# B    7
# C    9
# dtype: int64
# A     4
# B    10
# C    18
# dtype: int64
# A    0.25
# B    0.40
# C    0.50
# dtype: float64
# A      1
# B     32
# C    729
# dtype: int64

# %%
# Creating the Series
sr = pd.Series([10, 25, 3, 25, 24, 6])

# Create the Index
index_ = ['Coca Cola', 'Sprite', 'Coke', 'Fanta', 'Dew', 'ThumbsUp']

# set the index
sr.index = index_

# Print the series
print(sr)
# Out:
# Coca Cola    10
# Sprite       25
# Coke          3
# Fanta        25
# Dew          24
# ThumbsUp      6
# dtype: int64

# %%
# return the mean
result = sr.mean()

# Print the result
print(result)
# Out:
# 15.5

# %% [markdown]
# **Example #2: Use Series.mean() function to find the mean of the underlying data in the given series object. The given series object also contains some missing values.**

# %%
# Creating the Series
sr = pd.Series([19.5, 16.8, None, 22.78, 16.8, 20.124, None, 18.1002, 19.5])

# Print the series
print(sr)
# Out:
# 0    19.5000
# 1    16.8000
# 2        NaN
# 3    22.7800
# 4    16.8000
# 5    20.1240
# 6        NaN
# 7    18.1002
# 8    19.5000
# dtype: float64

# %%
# return the mean
# skip all the missing values
result = sr.mean(skipna = True)

print(result)
# Out:
# 19.086314285714284

# %% [markdown]
# **Code #1: By default, product of an empty or all-NA Series is 1.**

# %%
# min_count = 0 is the default
pd.Series([]).prod()

# When passed  min_count = 1, 
# product of an empty series will be NaN
pd.Series([]).prod(min_count = 1)
# Out:
# nan

# %%
# applying prod() on a list of series
val = pd.Series([12, 5, 7]).prod() 

val
# Out:
# np.int64(420)

# %% [markdown]
# **Series.abs() method is used to get the absolute numeric value of each element in Series/DataFrame.**

# %%
# creating lists
lst = [2, -10.87, -3.14, 0.12]
lst2 = [-10.87 + 4j]

ser = pd.Series(lst)
ser1 = pd.Series(lst2)

# printing values explaining abs()
print(ser1.abs(), '\n\n', ser.abs())
# Out:
# 0    11.582612
# dtype: float64
#
#  0     2.00
# 1    10.87
# 2     3.14
# 3     0.12
# dtype: float64

# %% [markdown]
#
# **Code #2: Explaining use of abs() on specific row**

# %%
df = pd.DataFrame({'Name': ['John', 'Hari', 'Peter', 'Loani'],
                  'Age': [31, 29, 57, 40],
                  'val': [98, 48, -80, -14]})


df['ope'] = (df.val - 87).abs()

df
# Out:
#     Name  Age  val  ope
# 0   John   31   98   11
# 1   Hari   29   48   39
# 2  Peter   57  -80  167
# 3  Loani   40  -14  101

# %% [markdown]
# **Conversion Operation on Series**
#
#
# Conversion operations allow transforming data types within a Series. This can be useful for ensuring consistency in data types. In order to perform conversion operation we have various function which help in conversion like .astype(), .tolist() etc

# %%
ser = pd.Series([1, 2, 3, 4])
ser = ser.astype(float)
print(ser)
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# dtype: float64

# %% [markdown]
# **DataFrames**

# %%
 
lst = ['Geeks', 'For', 'Geeks', 'is', 
            'portal', 'for', 'Geeks']

df = pd.DataFrame(lst)
print(df)
# Out:
#         0
# 0   Geeks
# 1     For
# 2   Geeks
# 3      is
# 4  portal
# 5     for
# 6   Geeks

# %% [markdown]
# **Creating DataFrame from dict of ndarray/lists**

# %%
data={'Name':['Palak','nick','karan','jack'],
      'Age':[20,21,19,18] }
      
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age
# 0  Palak   20
# 1   nick   21
# 2  karan   19
# 3   jack   18

# %%
 
data = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32],
        'Address':['Delhi', 'Kanpur', 'Allahabad', 'Kannauj'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']}
 
df = pd.DataFrame(data)
 
print(df[['Name', 'Qualification']])
# Out:
#      Name Qualification
# 0     Jai           Msc
# 1  Princi            MA
# 2  Gaurav           MCA
# 3    Anuj           Phd

# %% [markdown]
# ##  Dataframe Index

# %% [markdown]
# **Setting a Custom Index**

# %%
data ={'Name':['Palak','Sakshi'],
        'Age':[25,30],
        'Salary':[20000,40000]}
        
        
df = pd.DataFrame(data)
res= df.set_index('Name')
print(res)
# Out:
#         Age  Salary
# Name
# Palak    25   20000
# Sakshi   30   40000

# %% [markdown]
# ## Resetting index

# %%
data ={'Name':['Palak','Sakshi'],
        'Age':[25,30],
        'Salary':[20000,40000]}
        
        
df = pd.DataFrame(data)
res = df.reset_index(drop=True)
print(res)
# Out:
#      Name  Age  Salary
# 0   Palak   25   20000
# 1  Sakshi   30   40000

# %% [markdown]
# ## Indexing with loc

# %%
data ={'age':[25,30],
       'city': ['india','new york']}
df = pd.DataFrame(data,index=['Alice','Bob'])
row = df.loc['Alice']
print(row)
# Out:
# age        25
# city    india
# Name: Alice, dtype: object

# %% [markdown]
# ## Changing the index

# %%
data ={'age':[25,30],
       'city': ['india','new york']}
df = pd.DataFrame(data,index=['Alice','Bob'])
res = df.set_index('age')
print(res)
# Out:
#          city
# age
# 25      india
# 30   new york

# %% [markdown]
# ## DataFrame Access

# %%
import pandas as pd

data = {'Name': ['John', 'Alice', 'Bob', 'Eve', 'Charlie'], 
        'Age': [25, 30, 22, 35, 28], 
        'Gender': ['Male', 'Female', 'Male', 'Female', 'Male'], 
        'Salary': [50000, 55000, 40000, 70000, 48000]}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age  Gender  Salary
# 0     John   25    Male   50000
# 1    Alice   30  Female   55000
# 2      Bob   22    Male   40000
# 3      Eve   35  Female   70000
# 4  Charlie   28    Male   48000

# %% [markdown]
# ## Accessing Columns From DataFrame

# %%
df['Age']
# Out:
# 0    25
# 1    30
# 2    22
# 3    35
# 4    28
# Name: Age, dtype: int64

# %% [markdown]
# ## Accessing Rows by INDEX

# %%
df.iloc[1]
# Out:
# Name       Alice
# Age           30
# Gender    Female
# Salary     55000
# Name: 1, dtype: object

# %% [markdown]
# ## Accessing Multiple Rows or columns

# %%
df.loc[0:2,['Name' ,'Age']]
# Out:
#     Name  Age
# 0   John   25
# 1  Alice   30
# 2    Bob   22

# %% [markdown]
# ## Accessing Rows Based on Conditions

# %%
df[df['Age']>25]
# Out:
#       Name  Age  Gender  Salary
# 1    Alice   30  Female   55000
# 3      Eve   35  Female   70000
# 4  Charlie   28    Male   48000

# %% [markdown]
# ## Accessing Specific Cells with at and iat

# %% [markdown]
# .at[] method used for label based indexing
#
# .iat[] method used for integer based indexing

# %%
df.at[2,'Salary']
# Out:
# np.int64(40000)

# %% [markdown]
# ## Indexing Data using the[] Operator

# %% [markdown]
# ## Selecting a Single column

# %%
data = pd.read_csv(r"")
